# %% [markdown]
# <a href="https://colab.research.google.com/github/kuprel/min-dalle/blob/main/min_dalle.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # min(DALL·E)

# %% [markdown]
# ### Install

# %%
# !nvidia-smi
# !pip install .  # min-dalle
# Out:
# Thu Jul 21 18:35:43 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.73.01    Driver Version: 460.73.01    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  GeForce RTX 2070    Off  | 00000000:26:00.0  On |                  N/A |
# |  0%   54C    P8    37W / 215W |   1096MiB /  7974MiB |     36%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    0   N/A  N/A      1534      G   /usr/lib/xorg/Xorg                 35MiB |
# |    0   N/A  N/A      2515      G   /usr/lib/xorg/Xorg                492MiB |
# |    0   N/A  N/A      2651      G   /usr/bin/gnome-shell              137MiB |
# |    0   N/A  N/A      3745      G   /usr/lib/firefox/firefox          339MiB |
# |    0   N/A  N/A      7113      G   /home/ax37/Telegram/Telegram        1MiB |
# |    0   N/A  N/A      7383      G   ...AAAAAAAAA= --shared-files       51MiB |
# |    0   N/A  N/A      8311      G   /opt/zoom/zoom                     20MiB |
# |    0   N/A  N/A     24870      G   ...f_7639.log --shared-files        2MiB |
# +-----------------------------------------------------------------------------+
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Processing /home/ax37/code/py/min-dalle
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: torch>=1.11 in /home/ax37/anaconda3/lib/python3.8/site-packages (from min-dalle==0.3.16) (1.11.0+cu113)
# Requirement already satisfied: typing_extensions>=4.1 in /home/ax37/anaconda3/lib/python3.8/site-packages (from min-dalle==0.3.16) (4.3.0)
# Requirement already satisfied: numpy>=1.21 in /home/ax37/anaconda3/lib/python3.8/site-packages (from min-dalle==0.3.16) (1.23.1)
# Requirement already satisfied: pillow>=7.1 in /home/ax37/anaconda3/lib/python3.8/site-packages (from min-dalle==0.3.16) (9.2.0)
# Requirement already satisfied: requests>=2.23 in /home/ax37/anaconda3/lib/python3.8/site-packages (from min-dalle==0.3.16) (2.28.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/ax37/anaconda3/lib/python3.8/site-packages (from requests>=2.23->min-dalle==0.3.16) (1.26.9)
# Requirement already satisfied: idna<4,>=2.5 in /home/ax37/anaconda3/lib/python3.8/site-packages (from requests>=2.23->min-dalle==0.3.16) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ax37/anaconda3/lib/python3.8/site-packages (from requests>=2.23->min-dalle==0.3.16) (2022.6.15)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/ax37/anaconda3/lib/python3.8/site-packages (from requests>=2.23->min-dalle==0.3.16) (2.0.12)
# Building wheels for collected packages: min-dalle
#   Building wheel for min-dalle (setup.py) ... done
#   Created wheel for min-dalle: filename=min_dalle-0.3.16-py3-none-any.whl size=10608 sha256=9b7678766f4ac3b1636ce1162c3c7195cc87e089e74155b13444677ddbf98576
#   Stored in directory: /tmp/pip-ephem-wheel-cache-r2bqkq1g/wheels/48/bd/9b/68c69298e89eb34c33b1d37867594226d9362986989aeb3f46
# Successfully built min-dalle
# Installing collected packages: min-dalle
# Successfully installed min-dalle-0.3.16

# %% [markdown]
# ### Load Model
# `float32` is faster than `float16` but uses more GPU memory.  Change the `grid_size` to 3 or less if using `float32`.

# %%
dtype = "float16" #@param ["float32", "float16", "bfloat16"]
from IPython.display import display, update_display
import torch
from min_dalle import MinDalle

model = MinDalle(
    dtype=getattr(torch, dtype),
    device="cuda",
    is_mega=True, 
    is_reusable=True
)
# Out:
# using device cuda
# downloading tokenizer params
# intializing TextTokenizer
# downloading encoder params
# initializing DalleBartEncoder
# downloading decoder params
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [4], in <cell line: 6>()
#       3 import torch
#       4 from min_dalle import MinDalle
# ----> 6 model = MinDalle(
#       7     dtype=getattr(torch, dtype),
#       8     device="cuda",
#       9     is_mega=True,
#      10     is_reusable=True
#      11 )
#
# File ~/code/py/min-dalle/min_dalle/min_dalle.py:66, in MinDalle.__init__(self, models_root, dtype, device, is_mega, is_reusable, is_verbose)
#      64 if is_reusable:
#      65     self.init_encoder()
# ---> 66     self.init_decoder()
#      67     self.init_detokenizer()
#
# File ~/code/py/min-dalle/min_dalle/min_dalle.py:132, in MinDalle.init_decoder(self)
#     130 def init_decoder(self):
#     131     is_downloaded = os.path.exists(self.decoder_params_path)
# --> 132     if not is_downloaded: self.download_decoder()
#     133     if self.is_verbose: print("initializing DalleBartDecoder")
#     134     self.decoder = DalleBartDecoder(
#     135         image_vocab_count = self.image_vocab_count,
#     136         attention_head_count = self.attention_head_count,
#    (...)
#     140         device=self.device
#     141     ).to(self.dtype).eval()
#
# File ~/code/py/min-dalle/min_dalle/min_dalle.py:89, in MinDalle.download_decoder(self)
#      87 if self.is_verbose: print("downloading decoder params")
#      88 suffix = '' if self.is_mega else '_mini'
# ---> 89 params = requests.get(MIN_DALLE_REPO + 'decoder{}.pt'.format(suffix))
#      90 with open(self.decoder_params_path, 'wb') as f: f.write(params.content)
#
# File ~/anaconda3/lib/python3.8/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~/anaconda3/lib/python3.8/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/anaconda3/lib/python3.8/site-packages/requests/sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     582 send_kwargs = {
#     583     "timeout": timeout,
#     584     "allow_redirects": allow_redirects,
#     585 }
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File ~/anaconda3/lib/python3.8/site-packages/requests/sessions.py:723, in Session.send(self, request, **kwargs)
#     720 if allow_redirects:
#     721     # Redirect resolving generator.
#     722     gen = self.resolve_redirects(r, request, **kwargs)
# --> 723     history = [resp for resp in gen]
#     724 else:
#     725     history = []
#
# File ~/anaconda3/lib/python3.8/site-packages/requests/sessions.py:723, in <listcomp>(.0)
#     720 if allow_redirects:
#     721     # Redirect resolving generator.
#     722     gen = self.resolve_redirects(r, request, **kwargs)
# --> 723     history = [resp for resp in gen]
#     724 else:
#     725     history = []
#
# File ~/anaconda3/lib/python3.8/site-packages/requests/sessions.py:266, in SessionRedirectMixin.resolve_redirects(self, resp, req, stream, timeout, verify, cert, proxies, yield_requests, **adapter_kwargs)
#     263     yield req
#     264 else:
# --> 266     resp = self.send(
#     267         req,
#     268         stream=stream,
#     269         timeout=timeout,
#     270         verify=verify,
#     271         cert=cert,
#     272         proxies=proxies,
#     273         allow_redirects=False,
#     274         **adapter_kwargs,
#     275     )
#     277     extract_cookies_to_jar(self.cookies, prepared_request, resp.raw)
#     279     # extract redirect url, if any, for the next loop
#
# File ~/anaconda3/lib/python3.8/site-packages/requests/sessions.py:745, in Session.send(self, request, **kwargs)
#     742         pass
#     744 if not stream:
# --> 745     r.content
#     747 return r
#
# File ~/anaconda3/lib/python3.8/site-packages/requests/models.py:899, in Response.content(self)
#     897         self._content = None
#     898     else:
# --> 899         self._content = b"".join(self.iter_content(CONTENT_CHUNK_SIZE)) or b""
#     901 self._content_consumed = True
#     902 # don't need to release the connection; that's been handled by urllib3
#     903 # since we exhausted the data.
#
# File ~/anaconda3/lib/python3.8/site-packages/requests/models.py:816, in Response.iter_content.<locals>.generate()
#     814 if hasattr(self.raw, "stream"):
#     815     try:
# --> 816         yield from self.raw.stream(chunk_size, decode_content=True)
#     817     except ProtocolError as e:
#     818         raise ChunkedEncodingError(e)
#
# File ~/anaconda3/lib/python3.8/site-packages/urllib3/response.py:579, in HTTPResponse.stream(self, amt, decode_content)
#     577 else:
#     578     while not is_fp_closed(self._fp):
# --> 579         data = self.read(amt=amt, decode_content=decode_content)
#     581         if data:
#     582             yield data
#
# File ~/anaconda3/lib/python3.8/site-packages/urllib3/response.py:522, in HTTPResponse.read(self, amt, decode_content, cache_content)
#     520 else:
#     521     cache_content = False
# --> 522     data = self._fp.read(amt) if not fp_closed else b""
#     523     if (
#     524         amt != 0 and not data
#     525     ):  # Platform-specific: Buggy versions of Python.
#    (...)
#     531         # not properly close the connection in all cases. There is
#     532         # no harm in redundantly calling close.
#     533         self._fp.close()
#
# File ~/anaconda3/lib/python3.8/http/client.py:458, in HTTPResponse.read(self, amt)
#     455 if amt is not None:
#     456     # Amount is given, implement using readinto
#     457     b = bytearray(amt)
# --> 458     n = self.readinto(b)
#     459     return memoryview(b)[:n].tobytes()
#     460 else:
#     461     # Amount is not given (unbounded read) so we must check self.length
#     462     # and self.chunked
#
# File ~/anaconda3/lib/python3.8/http/client.py:502, in HTTPResponse.readinto(self, b)
#     497         b = memoryview(b)[0:self.length]
#     499 # we do not use _safe_read() here because this may be a .will_close
#     500 # connection, and the user is reading more bytes than will be provided
#     501 # (for example, reading in 1k chunks)
# --> 502 n = self.fp.readinto(b)
#     503 if not n and b:
#     504     # Ideally, we would raise IncompleteRead if the content-length
#     505     # wasn't satisfied, but it might break compatibility.
#     506     self._close_conn()
#
# File ~/anaconda3/lib/python3.8/socket.py:669, in SocketIO.readinto(self, b)
#     667 while True:
#     668     try:
# --> 669         return self._sock.recv_into(b)
#     670     except timeout:
#     671         self._timeout_occurred = True
#
# File ~/anaconda3/lib/python3.8/ssl.py:1241, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1237     if flags != 0:
#    1238         raise ValueError(
#    1239           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240           self.__class__)
# -> 1241     return self.read(nbytes, buffer)
#    1242 else:
#    1243     return super().recv_into(buffer, nbytes, flags)
#
# File ~/anaconda3/lib/python3.8/ssl.py:1099, in SSLSocket.read(self, len, buffer)
#    1097 try:
#    1098     if buffer is not None:
# -> 1099         return self._sslobj.read(len, buffer)
#    1100     else:
#    1101         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %% [markdown]
# ### Generate Images
#
# - `grid_size` Size of the image grid.  Reduce this if you run out of GPU memory.
#
# - `progressive_outputs` Whether to show intermediate output.  Adds a small delay and increases memory usage.
#
# - `seamless` Tiles the images in token space instead of pixel space
#
# - `supercondition_factor` Higher values result in better agreement with the text but a narrower variety of generated images
#
# - `top_k` Each image token is sampled from the top $k$ most probable tokens

# %%
# %%time

text = "Dali painting of WALL·E" #@param {type:"string"}
progressive_outputs = True #@param {type:"boolean"}
seamless = True #@param {type:"boolean"}
grid_size = 4 #@param {type:"integer"}
temperature = 2 #@param {type:"slider", min:0.01, max:3, step:0.01}
supercondition_factor = 16 #@param {type:"number"}
top_k = 128 #@param {type:"integer"}

image_stream = model.generate_image_stream(
    text=text,
    seed=-1,
    grid_size=grid_size,
    progressive_outputs=progressive_outputs,
    is_seamless=seamless,
    temperature=temperature,
    top_k=int(top_k),
    supercondition_factor=float(supercondition_factor)
)

is_first = True
for image in image_stream:
    display_image = display if is_first else update_display
    display_image(image, display_id=1)
    is_first = False
# Out:
# <PIL.Image.Image image mode=RGB size=1024x1024 at 0x7FA55DFEEE50>
# CPU times: user 55 s, sys: 771 ms, total: 55.8 s
# Wall time: 1min 3s
